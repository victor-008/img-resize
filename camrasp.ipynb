# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load model
model = YOLO('V:/coding/dev/Python/Gantry/FYP/best.pt')


def detect_camera():
    '''function to perform detection on a camera feed'''
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            print("Error: Could not read frame.")
            break

        #inference on the frame
        results = model(frame)

        # Extract results
        boxes = results[0].boxes.xyxy.cpu().numpy()  # Bounding boxes
        scores = results[0].boxes.conf.cpu().numpy()  # Confidence scores
        class_ids = results[0].boxes.cls.cpu().numpy().astype(int)  # Class IDs
        class_names = results[0].names  # Class names

        # Draw the results on the frame
        for box, score, class_id in zip(boxes, scores, class_ids):
            if score > 0.2:  # Threshold for displaying boxes
                x1, y1, x2, y2 = map(int, box[:4])
                class_name = class_names[class_id] if class_id < len(class_names) else f"Class {class_id}"
                label = f"{class_name}: {score:.2f}"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Display the resulting frame
        cv2.imshow('YOLOv8 Detection', frame)

        # Press 'q' to break out of the loop
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # release the capture and close windows
    cap.release()
    cv2.destroyAllWindows()

# Run the camera detection
detect_camera()
# Out:
# 0: 480x640 1 Other, 169.1ms
# Speed: 11.9ms preprocess, 169.1ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 95.2ms
# Speed: 1.9ms preprocess, 95.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 107.8ms
# Speed: 4.1ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 100.0ms
# Speed: 1.0ms preprocess, 100.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 80.3ms
# Speed: 2.5ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 87.9ms
# Speed: 2.3ms preprocess, 87.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 84.9ms
# Speed: 2.2ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 86.8ms
# Speed: 2.0ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 84.5ms
# Speed: 1.6ms preprocess, 84.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 83.6ms
# Speed: 2.4ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 87.2ms
# Speed: 0.0ms preprocess, 87.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 84.3ms
# Speed: 1.7ms preprocess, 84.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 96.5ms
# Speed: 1.6ms preprocess, 96.5ms inference, 53.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 94.2ms
# Speed: 0.0ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 94.0ms
# Speed: 0.0ms preprocess, 94.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 85.4ms
# Speed: 1.0ms preprocess, 85.4ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 84.6ms
# Speed: 2.2ms preprocess, 84.6ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 114.1ms
# Speed: 0.0ms preprocess, 114.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 109.2ms
# Speed: 2.1ms preprocess, 109.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 107.0ms
# Speed: 0.0ms preprocess, 107.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 90.9ms
# Speed: 2.0ms preprocess, 90.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 100.2ms
# Speed: 1.5ms preprocess, 100.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 95.5ms
# Speed: 1.5ms preprocess, 95.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 91.2ms
# Speed: 3.1ms preprocess, 91.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 90.6ms
# Speed: 1.8ms preprocess, 90.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 101.3ms
# Speed: 3.1ms preprocess, 101.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 95.7ms
# Speed: 1.6ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 89.3ms
# Speed: 1.5ms preprocess, 89.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 99.8ms
# Speed: 8.8ms preprocess, 99.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 84.4ms
# Speed: 2.1ms preprocess, 84.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 90.0ms
# Speed: 2.4ms preprocess, 90.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 89.5ms
# Speed: 2.1ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 86.3ms
# Speed: 1.6ms preprocess, 86.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 93.7ms
# Speed: 2.7ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 145.9ms
# Speed: 2.0ms preprocess, 145.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 92.0ms
# Speed: 2.8ms preprocess, 92.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 103.5ms
# Speed: 1.7ms preprocess, 103.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 96.4ms
# Speed: 1.1ms preprocess, 96.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 93.6ms
# Speed: 2.5ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 91.1ms
# Speed: 1.0ms preprocess, 91.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 96.7ms
# Speed: 1.9ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 83.8ms
# Speed: 1.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 113.3ms
# Speed: 3.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 108.4ms
# Speed: 2.0ms preprocess, 108.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 91.7ms
# Speed: 1.6ms preprocess, 91.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 87.7ms
# Speed: 2.9ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Black Rot Disease, 1 Other, 106.8ms
# Speed: 1.2ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 81.2ms
# Speed: 2.1ms preprocess, 81.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 91.0ms
# Speed: 1.5ms preprocess, 91.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 81.1ms
# Speed: 1.9ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Other, 87.5ms
# Speed: 2.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('V:/coding/dev/Python/Gantry/FYP/best.pt')

# Function to perform detection on a camera feed
def detect_camera():
    # Open a connection to the camera (0 is usually the default camera)
    cap = cv2.VideoCapture(0)

    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            print("Error: Could not read frame.")
            break

        # Perform inference on the frame
        results = model(frame)

        # Extract results
        boxes = results[0].boxes.xyxy.cpu().numpy()  # Bounding boxes
        scores = results[0].boxes.conf.cpu().numpy()  # Confidence scores
        class_ids = results[0].boxes.cls.cpu().numpy().astype(int)  # Class IDs
        class_names = results[0].names  # Class names

        # Draw the results on the frame
        for box, score, class_id in zip(boxes, scores, class_ids):
            if score > 0.2:  # Threshold for displaying boxes
                x1, y1, x2, y2 = map(int, box[:4])
                class_name = class_names[class_id] if class_id < len(class_names) else f"Class {class_id}"
                label = f"{class_name}: {score:.2f}"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Display the resulting frame
        cv2.imshow('YOLOv8 Detection', frame)

        # Press 'q' to break out of the loop
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture and close windows
    cap.release()
    cv2.destroyAllWindows()

# Run the camera detection
detect_camera()
